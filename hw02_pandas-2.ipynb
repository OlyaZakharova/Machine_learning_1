# %% [markdown]
# # Домашнее задание 2 (5 баллов).
#
# Все задания ниже имеют равный вес (5/16).

# %% [markdown]
# #### Описание данных
#
# В папке Data находится информация о студентах. Всего 10 групп студентов. Файлы делятся на две категории:
#     * Students_info_i - информация о студентах из группы i
#     * Students_marks_i - оценки студентов из группы i за экзамены

# %% [markdown]
# ### Одно из важных достоинств pandas $-$ это удобные методы реляционного взаимодействия с данными, аналогичные, например, возможностям SQL для слияния и конкатенации таблиц: merge, join, concat. Наличие готовых методов позволяет не реализовывать самостоятельно поэлементную обработку данных и оперировать сразу целыми таблицами данных.
#
# Подробно об этих методах посмотрите тут: https://www.kaggle.com/residentmario/renaming-and-combining#Combining

# %% [markdown]
# #### Задание 1. Соберите всю информацию о студентах в одну таблицу df. В получившейся таблице должна быть информация и оценки всех студентов из всех групп. Напечатайте несколько строк таблицы для демонстрации результата.¶

# %%
import numpy as np
import zipfile
import os
import pandas as pd

# %%
zip_file_path = '/content/Data.zip'

extract_to_folder ="/content"

# %%
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Распаковываем все содержимое в указанную папку
    zip_ref.extractall(extract_to_folder)

# %%
#your code here
students_info = pd.read_csv(f"/content/Data/Students_info_0.csv", sep = ",", index_col = 0)
print(students_info.shape)
for i in range(1, 10):
  students_info1 = pd.read_csv(f"/content/Data/Students_info_{i}.csv", sep = ",", index_col = 0)
  students_info = pd.concat([students_info, students_info1])
  print(students_info.shape)
# Out:
# (100, 6)
# (200, 6)
# (300, 6)
# (400, 6)
# (500, 6)
# (600, 6)
# (700, 6)
# (800, 6)
# (900, 6)
# (1000, 6)

# %%
students_info.head(10)
# Out:
#        gender race/ethnicity parental level of education         lunch  \
# index
# 0      female        group B           bachelor's degree      standard
# 1      female        group C                some college      standard
# 2      female        group B             master's degree      standard
# 3        male        group A          associate's degree  free/reduced
# 4        male        group C                some college      standard
# 5      female        group B          associate's degree      standard
# 6      female        group B                some college      standard
# 7        male        group B                some college  free/reduced
# 8        male        group D                 high school  free/reduced
# 9      female        group B                 high school  free/reduced
#
#       test preparation course   group
# index
# 0                        none  group1
# 1                   completed  group1
# 2                        none  group1
# ...

# %%
student_marks = pd.read_csv(f"/content/Data/Students_marks_0.csv", sep = ",", index_col = 0)
print(student_marks.shape)
for i in range(1, 10):
  student_marks1 = pd.read_csv(f"/content/Data/Students_marks_{i}.csv", sep = ",", index_col = 0)
  student_marks = pd.concat([student_marks, student_marks1])
  print(student_marks.shape)
# Out:
# (100, 3)
# (200, 3)
# (300, 3)
# (400, 3)
# (500, 3)
# (600, 3)
# (700, 3)
# (800, 3)
# (900, 3)
# (1000, 3)

# %%
student_marks.head(10)
# Out:
#        math score  reading score  writing score
# index
# 0              72             72             74
# 1              69             90             88
# 2              90             95             93
# 3              47             57             44
# 4              76             78             75
# 5              71             83             78
# 6              88             95             92
# 7              40             43             39
# 8              64             64             67
# 9              38             60             50

# %%
df = pd.merge(students_info, student_marks, on="index", how="outer")
print(df.shape)
df.head(10)
# Out:
# (1000, 9)
#        gender race/ethnicity parental level of education         lunch  \
# index
# 0      female        group B           bachelor's degree      standard
# 1      female        group C                some college      standard
# 2      female        group B             master's degree      standard
# 3        male        group A          associate's degree  free/reduced
# 4        male        group C                some college      standard
# 5      female        group B          associate's degree      standard
# 6      female        group B                some college      standard
# 7        male        group B                some college  free/reduced
# 8        male        group D                 high school  free/reduced
# 9      female        group B                 high school  free/reduced
#
#       test preparation course   group  math score  reading score  \
# index
# 0                        none  group1          72             72
# ...

# %% [markdown]
# #### Задание 2. Удалите столбец index у полученной таблицы. Напечатайте первые 10 строк таблицы.

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# group                          object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# #### Задание 3. Выведите на экран размеры полученной таблицы

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Задание 4. Выведите на экран статистические характеристики числовых столбцов таблицы (минимум, максимум, среднее значение, стандартное отклонение)

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# #### Задание 5. Проверьте, есть ли в таблице пропущенные значения

# %%
df[df == "Unknow"].count()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# group                          0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.replace("Unknow", pd.NA).isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# group                          0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# #### Задание 6. Выведите на экран средние баллы студентов по каждому предмету (math, reading, writing)

# %%
df['math score'].mean()
# Out:
# 66.089

# %%
df['reading score'].mean()
# Out:
# 69.169

# %%
df['writing score'].mean()
# Out:
# 68.054

# %% [markdown]
# **Задание 7. Как зависят оценки от того, проходил ли студент курс для подготовки к сдаче экзамена (test preparation course)? Выведите на экран для каждого предмета в отдельности средний балл студентов, проходивших курс для подготовки к экзамену и не проходивших курс.**

# %%
# конвертируем строки в числа
df['math score'] = pd.to_numeric(df['math score'], errors='coerce')
df['reading score'] = pd.to_numeric(df['reading score'], errors='coerce')
df['writing score'] = pd.to_numeric(df['writing score'], errors='coerce')

# %%
completed_course = df[df["test preparation course"] == "completed"]
not_completed_course = df[df['test preparation course'] == "none"]
print(f"completed_course:{completed_course.shape[0]}")
print(f"not_completed_course:{not_completed_course.shape[0]}")
# Out:
# completed_course:358
# not_completed_course:642

# %%
completed_course[['math score', 'reading score', 'writing score']].mean()
# Out:
# math score       69.695531
# reading score    73.893855
# writing score    74.418994
# dtype: float64

# %%
not_completed_course[['math score', 'reading score', 'writing score']].mean()
# Out:
# math score       64.077882
# reading score    66.534268
# writing score    64.504673
# dtype: float64

# %% [markdown]
# **Задание 8. Выведите на экран все различные значения из столбца lunch.**

# %%
df['lunch'].nunique()
# Out:
# 2

# %%
df['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %% [markdown]
# **Задание 9. Переименуйте колонку "parental level of education" в "education", а "test preparation course" в "test preparation" с помощью метода pandas rename**
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
df = df.rename(columns={"parental level of education": "education", "test preparation course": "test preparation"})
df.head()
# Out:
#        gender race/ethnicity           education         lunch  \
# index
# 0      female        group B   bachelor's degree      standard
# 1      female        group C        some college      standard
# 2      female        group B     master's degree      standard
# 3        male        group A  associate's degree  free/reduced
# 4        male        group C        some college      standard
#
#       test preparation   group  math score  reading score  writing score
# index
# 0                 none  group1          72             72             74
# 1            completed  group1          69             90             88
# 2                 none  group1          90             95             93
# 3                 none  group1          47             57             44
# 4                 none  group1          76             78             75

# %% [markdown]
# **Зафиксируем минимальный балл для сдачи экзамена**

# %%
passmark = 50

# %% [markdown]
# **Задание 10. Ответьте на вопросы:**
#     * Какая доля студентов сдала экзамен по математике (passmark >= 50)?
#     * Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?
#     * Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?

# %%
# доля студентов сдала экзамен по математике >=50
percentage_outliers = (df[df['math score'] >= passmark].shape[0]/df.shape[0])*100
print(f"percentage_outliers: {percentage_outliers:.2f}")
# Out:
# percentage_outliers: 86.50

# %%
#Какая доля студентов, проходивших курс подготовки к экзамену,
#сдала экзамен по математике?

human_completed = df.loc[(df['test preparation'] == "completed") & (df["math score"] > passmark)].shape[0]
#human_zero =  df.loc[df["math score"] > passmark].shape[0]
#print(human_zero)

print(human_completed)

percentage_outliers_completed = (human_completed/df.shape[0])*100

print(f"percentage_outliers_completed: {percentage_outliers_completed: .2f}")
# Out:
# 850
# 325
# percentage_outliers_completed:  32.50

# %%
#Какая доля женщин, не проходивших курс подготовки к экзамену,
#не сдала экзамен по математике?

woman_non_math = df.loc[(df['test preparation'] == "none") & (df["math score"] < passmark) & (df["gender"] == 'female')].shape[0]


print(woman_non_math)

percentage_outliers_woman_non_math = (woman_non_math/df.shape[0])*100

print(f"percentage_outliers_woman_non_math: {percentage_outliers_woman_non_math: .2f}")
# Out:
# 70
# percentage_outliers_woman_non_math:  7.00

# %% [markdown]
# **Задание 11. С помощью groupby выполните задания ниже. Также выведите время выполнения каждого из заданий.**
#     * Для каждой этнической группы выведите средний балл за экзамен по чтению
#     * Для каждого уровня образования выведите минимальный балл за экзамен по письму

# %%
# %%timeit
#Для каждой этнической группы выведите средний балл за экзамен по чтению

avg_race_reading = df.groupby("race/ethnicity")['reading score'].mean()
print(avg_race_reading)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Name: reading score, dtype: float64
# race/ethnicity
# group A    64.674157
# group B    67.352632
# group C    69.103448
# group D    70.030534
# group E    73.028571
# Name: reading score, dtype: float64
# race/ethnicity
# group A    64.674157
# group B    67.352632
# group C    69.103448
# group D    70.030534
# group E    73.028571
# Name: reading score, dtype: float64
# race/ethnicity
# group A    64.674157
# group B    67.352632
# group C    69.103448
# group D    70.030534
# group E    73.028571
# Name: reading score, dtype: float64
# race/ethnicity
# group A    64.674157
# group B    67.352632
# group C    69.103448
# group D    70.030534
# group E    73.028571
# Name: reading score, dtype: float64
# race/ethnicity
# group A    64.674157
# group B    67.352632
# group C    69.103448
# group D    70.030534
# group E    73.028571
# Name: reading score, dtype: float64
# race/ethnicity
# group A    64.674157
# ...

# %%
# %%timeit
#Для каждого уровня образования выведите минимальный балл за экзамен по письму

min_education_writing  = df.groupby("education")['writing score'].min()
print(min_education_writing)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# associate's degree    35
# bachelor's degree     38
# high school           15
# master's degree       46
# some college          19
# some high school      10
# Name: writing score, dtype: int64
# education
# associate's degree    35
# bachelor's degree     38
# high school           15
# master's degree       46
# some college          19
# some high school      10
# Name: writing score, dtype: int64
# education
# associate's degree    35
# bachelor's degree     38
# high school           15
# master's degree       46
# some college          19
# some high school      10
# Name: writing score, dtype: int64
# education
# associate's degree    35
# bachelor's degree     38
# high school           15
# master's degree       46
# some college          19
# some high school      10
# Name: writing score, dtype: int64
# education
# associate's degree    35
# bachelor's degree     38
# high school           15
# ...

# %% [markdown]
# **Задание 12. Выполните задание 11 с помощью циклов. Сравните время выполнения.**

# %%
df["race/ethnicity"].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
# %%timeit

race = ['group A', 'group B', 'group C', 'group D', 'group E']

for i in race:
  avg_race_reading = df[df['race/ethnicity'] == i]['reading score'].mean()
  print(f'avg_race_reading{i}: {avg_race_reading:.2f}')
# Out:
# avg_race_readinggroup A: 64.67
# avg_race_readinggroup B: 67.35
# avg_race_readinggroup C: 69.10
# avg_race_readinggroup D: 70.03
# avg_race_readinggroup E: 73.03
# avg_race_readinggroup A: 64.67
# avg_race_readinggroup B: 67.35
# avg_race_readinggroup C: 69.10
# avg_race_readinggroup D: 70.03
# avg_race_readinggroup E: 73.03
# avg_race_readinggroup A: 64.67
# avg_race_readinggroup B: 67.35
# avg_race_readinggroup C: 69.10
# avg_race_readinggroup D: 70.03
# avg_race_readinggroup E: 73.03
# avg_race_readinggroup A: 64.67
# avg_race_readinggroup B: 67.35
# avg_race_readinggroup C: 69.10
# avg_race_readinggroup D: 70.03
# avg_race_readinggroup E: 73.03
# avg_race_readinggroup A: 64.67
# avg_race_readinggroup B: 67.35
# avg_race_readinggroup C: 69.10
# avg_race_readinggroup D: 70.03
# avg_race_readinggroup E: 73.03
# avg_race_readinggroup A: 64.67
# avg_race_readinggroup B: 67.35
# avg_race_readinggroup C: 69.10
# avg_race_readinggroup D: 70.03
# avg_race_readinggroup E: 73.03
# ...

# %%
df["education"].value_counts()
# Out:
# education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
# %%timeit
education = ['some college', "associate's degree", "high school", "some high school", "bachelor's degree", "master's degree"]

for i in education:
  min_education_writing = df[df['education'] == i]['writing score'].mean()
  print(f'min_education_writing{i}: {min_education_writing:.2f}')
# Out:
# min_education_writingsome college: 68.84
# min_education_writingassociate's degree: 69.90
# min_education_writinghigh school: 62.45
# min_education_writingsome high school: 64.89
# min_education_writingbachelor's degree: 73.38
# min_education_writingmaster's degree: 75.68
# min_education_writingsome college: 68.84
# min_education_writingassociate's degree: 69.90
# min_education_writinghigh school: 62.45
# min_education_writingsome high school: 64.89
# min_education_writingbachelor's degree: 73.38
# min_education_writingmaster's degree: 75.68
# min_education_writingsome college: 68.84
# min_education_writingassociate's degree: 69.90
# min_education_writinghigh school: 62.45
# min_education_writingsome high school: 64.89
# min_education_writingbachelor's degree: 73.38
# min_education_writingmaster's degree: 75.68
# min_education_writingsome college: 68.84
# min_education_writingassociate's degree: 69.90
# min_education_writinghigh school: 62.45
# ...

# %% [markdown]
# **Задание 13. Выведите на экран средние баллы студентов по каждому предмету в зависимости от пола и уровня образования. То есть должно получиться количество групп, равных 2 * (число уровней образования), и для каждой такой группы выыведите средний балл по каждому из предметов.**
#
# Это можно сделать с помощью сводных таблиц (pivot_table):
#
# https://www.kaggle.com/kamilpolak/tutorial-how-to-use-pivot-table-in-pandas

# %%
grouped = pd.pivot_table(df,index=['gender','education'],
                         aggfunc={'math score':np.mean,'reading score':np.mean, 'writing score': np.mean})
grouped
# Out:
#                            math score  reading score  writing score
# gender education
# female associate's degree   65.250000      74.120690      74.000000
#        bachelor's degree    68.349206      77.285714      78.380952
#        high school          59.351064      68.202128      66.691489
#        master's degree      66.500000      76.805556      77.638889
#        some college         65.406780      73.550847      74.050847
#        some high school     59.296703      69.109890      68.285714
# male   associate's degree   70.764151      67.433962      65.405660
#        bachelor's degree    70.581818      68.090909      67.654545
#        high school          64.705882      61.480392      58.539216
#        master's degree      74.826087      73.130435      72.608696
#        some college         69.009259      64.990741      63.148148
#        some high school     67.840909      64.693182      61.375000

# %% [markdown]
# #### Задание 14. Сколько студентов успешно сдали экзамен по математике?
#
# Создайте новый столбец в таблице df под названием Math_PassStatus и запишите в него F, если студент не сдал экзамен по математике (балл за экзамен < passmark), и P иначе.
#
# Посчитайте количество студентов, сдавших и не сдавших экзамен по математике.
#
# Сделайте аналогичные шаги для экзаменов по чтению и письму.

# %%
df["Math_PassStatus"] = df['math score'].apply(lambda x: "P" if x > passmark else "F")

print(df["Math_PassStatus"].value_counts())

#df.head()
# Out:
# Math_PassStatus
# P    850
# F    150
# Name: count, dtype: int64

# %%
df["reading_PassStatus"] = df['reading score'].apply(lambda x: "P" if x > passmark else "F")

print(df["reading_PassStatus"].value_counts())

#df.head()
# Out:
# reading_PassStatus
# P    903
# F     97
# Name: count, dtype: int64

# %%
df["writing_PassStatus"] = df['writing score'].apply(lambda x: "P" if x > passmark else "F")

print(df["writing_PassStatus"].value_counts())

#df.head()
# Out:
# writing_PassStatus
# P    876
# F    124
# Name: count, dtype: int64

# %% [markdown]
# #### Задание 15. Сколько студентов успешно сдали все экзамены?
#
# Создайте столбец OverAll_PassStatus и запишите в него для каждого студента 'F', если студент не сдал хотя бы один из трех экзаменов, а иначе 'P'.
#
# Посчитайте количество студентов, которые сдали все экзамены.

# %%
df.head()
# Out:
#        gender race/ethnicity           education         lunch  \
# index
# 0      female        group B   bachelor's degree      standard
# 1      female        group C        some college      standard
# 2      female        group B     master's degree      standard
# 3        male        group A  associate's degree  free/reduced
# 4        male        group C        some college      standard
#
#       test preparation   group  math score  reading score  writing score  \
# index
# 0                 none  group1          72             72             74
# 1            completed  group1          69             90             88
# 2                 none  group1          90             95             93
# 3                 none  group1          47             57             44
# 4                 none  group1          76             78             75
#
#       Math_PassStatus reading_PassStatus writing_PassStatus
# index
# 0                   P                  P                  P
# ...

# %%
df["OverAll_PassStatus"] = df.apply(lambda x: "P" if (x['Math_PassStatus'] == "P") & (x["reading_PassStatus"] == "P") & (x["writing_PassStatus"] == "P") else "F", axis=1)

df.head()
# Out:
#        gender race/ethnicity           education         lunch  \
# index
# 0      female        group B   bachelor's degree      standard
# 1      female        group C        some college      standard
# 2      female        group B     master's degree      standard
# 3        male        group A  associate's degree  free/reduced
# 4        male        group C        some college      standard
#
#       test preparation   group  math score  reading score  writing score  \
# index
# 0                 none  group1          72             72             74
# 1            completed  group1          69             90             88
# 2                 none  group1          90             95             93
# 3                 none  group1          47             57             44
# 4                 none  group1          76             78             75
#
#       Math_PassStatus reading_PassStatus writing_PassStatus OverAll_PassStatus
# index
# ...

# %% [markdown]
# #### Задание 16. Переведем баллы в оценки
#
# ### Система перевода баллов в оценки
# ####    больше 90 = A
# ####      80-90 = B
# ####      70-80 = C
# ####      60-70 = D
# ####      50-60 = E
# ####    меньше 50 = F (Fail)
#
# Создайте вспомогательную функцию, которая будет по среднему баллу за три экзамена выставлять оценку студенту по данным выше критериям.
#
# Создайте столбец Grade и запишите в него оценку каждого студента.
#
# Выведите количество студентов, получивших каждую из оценок.
#
# **В случае, если средний балл попадает на границу между оценками (т.е. равен ровно 60, 70 или 80 баллов), вы можете интерпретировать условие на своё усмотрение (т.е. можете поставить за 60 баллов оценку D, а можете - E).**

# %%
df["Mean_score"] = df[["math score", 'reading score','writing score']].mean(axis = 1)
df.head()
# Out:
#        gender race/ethnicity           education         lunch  \
# index
# 0      female        group B   bachelor's degree      standard
# 1      female        group C        some college      standard
# 2      female        group B     master's degree      standard
# 3        male        group A  associate's degree  free/reduced
# 4        male        group C        some college      standard
#
#       test preparation   group  math score  reading score  writing score  \
# index
# 0                 none  group1          72             72             74
# 1            completed  group1          69             90             88
# 2                 none  group1          90             95             93
# 3                 none  group1          47             57             44
# 4                 none  group1          76             78             75
#
#       Math_PassStatus reading_PassStatus writing_PassStatus  \
# index
# ...

# %%
def GetGrade(average_mark):
    if average_mark >= 90:
      return "A"
    elif 90 > average_mark >= 80:
      return "B"
    elif 80 > average_mark >= 70:
      return "C"
    elif 70 > average_mark >= 60:
      return "D"
    elif 60 > average_mark >= 50:
      return "E"
    elif average_mark < 50:
      return "F"

# your code here

df['Grade'] = df.apply(lambda x: GetGrade(x['math score']), axis = 1)

# %%
df.head()
# Out:
#        gender race/ethnicity           education         lunch  \
# index
# 0      female        group B   bachelor's degree      standard
# 1      female        group C        some college      standard
# 2      female        group B     master's degree      standard
# 3        male        group A  associate's degree  free/reduced
# 4        male        group C        some college      standard
#
#       test preparation   group  math score  reading score  writing score  \
# index
# 0                 none  group1          72             72             74
# 1            completed  group1          69             90             88
# 2                 none  group1          90             95             93
# 3                 none  group1          47             57             44
# 4                 none  group1          76             78             75
#
#       Math_PassStatus reading_PassStatus writing_PassStatus  \
# index
# ...
